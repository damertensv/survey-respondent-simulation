# %% [markdown]
# ## Preamble

# %%
import json
import pyreadstat
import pandas as pd

from typing import Any
from ipywidgets import interact
from collections import OrderedDict
from tqdm import tqdm
from colorama import Fore, Style


def spss_to_dict(file_path: str, verbose: bool = False) -> OrderedDict[str, dict[str, Any]]:
    df, meta = pyreadstat.read_sav(file_path)
    df_labeled = pyreadstat.set_value_labels(df, meta)
    gss_resp: OrderedDict[str, dict[str, Any]] = OrderedDict()
    for col in tqdm(df_labeled.columns, disable=not verbose, desc=r"[cols processed]"):
        clean_resp: list[str | None] = []
        for val in df_labeled[col].tolist():
            if pd.isna(val):
                clean_resp.append(None)
            else:
                clean_resp.append(str(val))
        support: OrderedDict[int, str] | None = None
        if col in meta.variable_value_labels:
            support = OrderedDict((code, label) for code, label in sorted(
                meta.variable_value_labels[col].items(), key=lambda x: x[0]
            ) if 0 <= code)
        gss_resp[col] = {
            "question": _no_qst_abbr(meta.column_names_to_labels.get(col, None)),
            "type": _infer_type(clean_resp, support),
            "responses": clean_resp,
            "support": support
        }
    return gss_resp

def _no_qst_abbr(text: str | None) -> str | None:
    if text is None:
        return None
    text = text.strip()
    if text.endswith(" r"):
        text = text[:-1] + "respondent"
    if text.startswith("r'") or text.startswith("r "):
        text = "respondent" + text[1:]
    text = text.replace(" r'", " respondent'")
    text = text.replace(" r ", " respondent ")
    return text

def _infer_type(resps: list[str | None], support: OrderedDict[int, str] | None) -> str:
    if _is_number(resps, support):
        return "scalar"
    return "categorical"

def _is_number(resps: list[str | None], support: OrderedDict[int, str] | None) -> bool:
    support = OrderedDict() if support is None else support
    resps = [r for r in resps if r is not None]
    if len(support) < len({r for r in resps}):
        return True
    return False

# %%
def col(txt: str, col: str) -> str:
    return f"{col}{txt}{Style.RESET_ALL}"

# %%
core_vars_superset = [
    # Demographic and life-course data
    'AGE', 'ZODIAC', 'COHORT',
    'SEX', 'SEXBIRTH1', 'SEXNOW1', 'SEXNOW2',
    'RACE', 'RACECEN1', 'RACECEN2', 'RACECEN3',
    'RACEACS1', 'RACEACS2', 'RACEACS3', 'RACEACS4', 'RACEACS5',
    'RACEACS6', 'RACEACS7', 'RACEACS8', 'RACEACS9', 'RACEACS10',
    'RACEACS11', 'RACEACS12', 'RACEACS13', 'RACEACS14', 'RACEACS15', 'RACEACS16',
    'ETHNIC', 'ETH1', 'ETH2', 'ETH3',
    'ETHWORLD1', 'ETHWORLD2', 'ETHWORLD3', 'ETHWORLD4', 'ETHWORLD5',
    'ETHWORLD6', 'ETHWORLD7', 'ETHWORLD8', 'ETHWORLD9',
    'ETHREGION1', 'ETHREGION2', 'ETHREGION3', 'ETHREGION4', 'ETHREGION5',
    'ETHREGION6', 'ETHREGION7', 'ETHREGION8', 'ETHREGION9', 'ETHREGION10',
    'ETHREGION11', 'ETHREGION12', 'ETHREGION13', 'ETHREGION14', 'ETHREGION15',
    'ETHREGION16', 'ETHREGION17', 'ETHREGION18', 'ETHREGION19', 'ETHREGION20',
    'ETHREGION21', 'ETHREGION22', 'ETHREGION23', 'ETHREGION24', 'ETHREGION25',
    'ETHREGION26', 'ETHREGION27', 'ETHREGION28', 'ETHREGION29', 'ETHREGION30',
    'ETHREGION31', 'ETHREGION32', 'ETHREGION33', 'ETHREGION34', 'ETHREGION35',
    'ETHREGION36', 'ETHREGION37', 'ETHREGION38', 'ETHREGION39', 'ETHREGION40',
    'ETHREGION41', 'ETHREGION42', 'ETHREGION43', 'ETHREGION44', 'ETHREGION45',
    'ETHREGION46', 'ETHREGION47', 'ETHREGION48', 'ETHREGION49', 'ETHREGION50',
    'ETHREGION51', 'ETHREGION52', 'ETHREGION53', 'ETHREGION54', 'ETHREGION55',
    'ETHREGION56', 'ETHREGION57', 'ETHREGION58', 'ETHREGION59', 'ETHREGION60',
    'ETHREGION61', 'ETHREGION62', 'ETHREGION63', 'ETHREGION64', 'ETHREGION65',
    'ETHREGION66', 'ETHREGION67', 'ETHREGION68', 'ETHREGION69', 'ETHREGION70',
    'ETHREGION71', 'ETHREGION72', 'ETHREGION73', 'ETHREGION74', 'ETHREGION75',
    'ETHREGION76', 'ETHREGION77', 'ETHREGION78', 'ETHREGION79', 'ETHREGION80',
    'ETHREGION81', 'ETHREGION82', 'ETHREGION83', 'ETHREGION84', 'ETHREGION85',
    'ETHREGION86', 'ETHREGION87', 'ETHREGION88', 'ETHREGION89', 'ETHREGION90',
    'ETHREGION91', 'ETHREGION92', 'ETHREGION93', 'ETHREGION94', 'ETHREGION95',
    'HISPANIC', 'SIBS',
    'MARITAL', 'WIDOWED', 'DIVORCE', 'MARTYPE', 'POSSLQ', 'POSSLQY', 'MARCOHAB',
    'CHILDS', 'AGEKDBRN',
    'REGION', 'XNORCSIZ', 'SRCBELT', 'SIZE',
    'EDUC', 'DEGREE', 'MAJOR1', 'MAJOR2', 'DIPGED',
    'RELIG', 'DENOM', 'OTHER', 'JEW', 'RELITEN', 'RELITENV', 'RELITENNV',
    'FUND', 'RELTRAD', 'NORELGSP',
    'INCOME', 'INCOME16', 'CONINC', 'REALINC',
    'USCITZN', 'USCITZNV', 'USCITZNNV', 'FUCITZN', 'FUCITZNV', 'FUCITZNNV',
    'MNTHSUSA', 'YEARSUSA',
    'OTHLANG', 'OTHLANG1', 'OTHLANG2', 'BETRLANG', 'SPKLANG',
    'SEXORNT',
    
    # Work/employment data
    'WRKSTAT', 'EVWORK', 'WRKSLF', 'WRKSLFFAM', 'WHATSLF2',
    'INDUS10', 'WRKGOVT1', 'WRKGOVT2', 'NUMEMPS',
    'HRS1', 'HRS2', 'WEEKSWRK', 'PARTFULL',
    'OCC10', 'PRESTG10', 'PRESTG105PLUS', 'SEI10', 'SEI10EDUC', 'SEI10INC',
    'RINCOME', 'RINCOM16', 'CONRINC', 'REALRINC',
    'LOCALNUM',
    'WKSUB', 'WKSUBS', 'WKSUP', 'WKSUPS', 'WKSUB1', 'WKSUBS1',
    'WKSUP1', 'WKSUPS1', 'YOUSUP', 'SPWKSUP', 'COWKSUP',
    
    # Military data
    'VETYEARS', 'VIETDRAFT',
    
    # Spouse/partner data
    'SPEDUC', 'SPDEG', 'COEDUC', 'CODEG',
    'SPWRKSTA', 'SPEVWORK', 'SPWRKSLF', 'SPWRKSLFFAM', 'SPWRKSLF2', 'WHATSP2',
    'COWRKSTA', 'COEVWORK', 'COWRKSLF', 'COWRKSLFFAM', 'COWRKSLF2', 'WHATCO2',
    'SPIND10', 'COIND10',
    'SPHRS1', 'SPHRS2', 'COHRS1', 'COHRS2',
    'SPOCC10', 'COOCC10',
    'SPPRES10', 'SPPRES105PLUS', 'SPSEI10', 'SPSEI10EDUC', 'SPSEI10INC',
    'COPRES10', 'COPRES105PLUS', 'COSEI10', 'COSEI10EDUC', 'COSEI10INC',
    'SPREL', 'SPDEN', 'SPOTHER', 'SPJEW', 'SPFUND', 'SPNORELGSP',
    'COREL', 'CODEN', 'COOTHER', 'COJEW', 'COFUND', 'CONORELGSP',
    
    # Parental/social origin data
    'BORN', 'INCOM16', 'FAMILY16', 'FAMILY16SEX', 'FAMDIF16', 'FAMDIF16Y',
    'PAEDUC', 'PADEG', 'MAEDUC', 'MADEG',
    'PAWRKSLF', 'PAWRKSLF2', 'PAWRKSLFFAM', 'WHATPA2', 'PAWRKGRW',
    'PAOCC10', 'PAIND10',
    'PAPRES10', 'PAPRES105PLUS', 'PASEI10', 'PASEI10EDUC', 'PASEI10INC',
    'MAWRKGRW', 'MAWRKSLF', 'MAWRKSLF2', 'MAWRKSLFFAM', 'WHATMA2',
    'MAOCC10', 'MAIND10',
    'MAPRES10', 'MAPRES105PLUS', 'MASEI10', 'MASEI10EDUC', 'MASEI10INC',
    'MABORN', 'PABORN', 'PARBORN', 'GRANBORN',
    'REG16', 'RES16', 'MOBILE16',
    'RELIG16', 'DENOM16', 'OTH16', 'JEW16', 'FUND16', 'NORELGSP16',
    
    # Household variables
    'HOMPOP', 'BABIES', 'PRETEEN', 'TEENS', 'ADULTS', 'UNRELAT',
    'ADULTSINHH', 'CHILDSINHH',
    'RELATE1', 'RELATE2', 'RELATE3', 'RELATE4', 'RELATE5', 'RELATE6',
    'RELATE7', 'RELATE8', 'RELATE9', 'RELATE10', 'RELATE11', 'RELATE12',
    'RELATE13', 'RELATE14',
    'RELHHD1', 'RELHHD2', 'RELHHD3', 'RELHHD4', 'RELHHD5', 'RELHHD6',
    'RELHHD7', 'RELHHD8', 'RELHHD9', 'RELHHD10', 'RELHHD11', 'RELHHD12',
    'RELHHD13', 'RELHHD14',
    'RELHH1', 'RELHH2', 'RELHH3', 'RELHH4', 'RELHH5', 'RELHH6',
    'RELHH7', 'RELHH8', 'RELHH9', 'RELHH10', 'RELHH11', 'RELHH12',
    'RELHH13', 'RELHH14',
    'RELSP1', 'RELSP2', 'RELSP3', 'RELSP4', 'RELSP5', 'RELSP6',
    'RELSP7', 'RELSP8', 'RELSP9', 'RELSP10', 'RELSP11', 'RELSP12',
    'RELSP13', 'RELSP14',
    'GENDER1', 'GENDER2', 'GENDER3', 'GENDER4', 'GENDER5', 'GENDER6',
    'GENDER7', 'GENDER8', 'GENDER9', 'GENDER10', 'GENDER11', 'GENDER12',
    'GENDER13', 'GENDER14',
    'OLD1', 'OLD2', 'OLD3', 'OLD4', 'OLD5', 'OLD6',
    'OLD7', 'OLD8', 'OLD9', 'OLD10', 'OLD11', 'OLD12',
    'OLD13', 'OLD14',
    'MAR1', 'MAR2', 'MAR3', 'MAR4', 'MAR5', 'MAR6',
    'MAR7', 'MAR8', 'MAR9', 'MAR10', 'MAR11', 'MAR12',
    'MAR13', 'MAR14',
    'AWAY1', 'AWAY2', 'AWAY3', 'AWAY4', 'AWAY5', 'AWAY6',
    'AWAY7', 'AWAY8', 'AWAY9', 'AWAY10', 'AWAY11', 'AWAY12',
    'AWAY13', 'AWAY14',
    'WHERE1', 'WHERE2', 'WHERE3', 'WHERE4', 'WHERE5', 'WHERE6',
    'WHERE7', 'WHERE8', 'WHERE9', 'WHERE10', 'WHERE11', 'WHERE12',
    'WHERE13', 'WHERE14',
    'HHRACE', 'HHTYPE', 'HHTYPE1', 'FAMGEN', 'RPLACE',
    'VISITORS', 'RVISITOR', 'EARNRS', 'DWELLING',
    'HOMPOP_EXP', 'BABIES_EXP', 'PRETEEN_EXP', 'TEENS_EXP', 'ADULTS_EXP', 'CHILDS_EXP',
    'HHTYPE1_EXP', 'FAMGEN_EXP',
    
    # Racial composition of neighborhood
    'RACLIVE',
    
    # Technical data and paradata
    'HLTHSTRT', 'HUADD', 'HUADDWHY', 'DWELLPRE', 'KIDSINHH', 'RESPOND',
    'INCUSPOP', 'NEISAFE',
    'RLOOKS', 'RGROOMED', 'RWEIGHT', 'RHLTHEND', 'HUCLEAN', 'COOP', 'COMPREND',
    'CONSENT', 'ADMINCONSENT',
    'WHOELSE1', 'WHOELSE2', 'WHOELSE3', 'WHOELSE4', 'WHOELSE5', 'WHOELSE6',
    'LNGTHINV', 'INTAGE', 'INTETHN', 'INTSEX', 'INTYRS', 'INTHISP',
    'INTRACE1', 'INTRACE2', 'INTRACE3',
    'RATETONE', 'PERLA',
    'MODE', 'MODESEQUENCE',
    'FEEUSED', 'FEELEVEL', 'TOTALINCENTIVE',
    'SPANENG', 'SPANINT', 'SPANSELF',
    'FORMWT', 'OVERSAMP', 'WTSS', 'WTSSALL', 'WTSSNR', 'WTSSPS', 'WTSSNRPS',
    'BALLOTFORMWT', 'BALLOTFORMWTNR', 'WTSSPS_AS', 'WTSSNRPS_AS',
    'ID', 'ANESID', 'HEFINFO', 'HEFINFO1',
    'RESPNUM', 'RESPNUMH',
    'YEAR', 'DATEINTV', 'BALLOT', 'VERSION', 'FORM',
    'ISSP', 'PHONE', 'SAMPLE', 'SAMPCODE', 'PHASE', 'SUBSAMPRATE', 'BATCH',
    'KISH', 'VPSU', 'VSTRAT', 'FILEVERSION', 'DEVTYPE',
    
    # Attitudes and Opinions - Priorities for national spending
    'NATSPAC', 'NATSPACY', 'NATENVIR', 'NATENVIRY', 'NATHEAL', 'NATHEALY',
    'NATCITY', 'NATCITYY', 'NATCRIME', 'NATCRIMEY', 'NATDRUG', 'NATDRUGY',
    'NATEDUC', 'NATEDUCY', 'NATRACE', 'NATRACEY', 'NATARMS', 'NATARMSY',
    'NATAID', 'NATAIDY', 'NATFARE', 'NATFAREY', 'NATROAD', 'NATSOC',
    'NATMASS', 'NATPARK', 'NATCHLD', 'NATSCI', 'NATENRGY',
    
    # Voting and political preferences
    'VOTE16', 'VOTE20', 'PRES16', 'PRES20', 'IF16WHO', 'IF20WHO',
    'POLVIEWS', 'PARTYID',
    
    # Religious attitudes and behavior
    'ATTEND', 'PRAY'
]
core_vars_superset = [v.lower() for v in core_vars_superset]

# %%
data = spss_to_dict("./2024_spss/2024/GSS2024.sav", verbose=True)
# Out:
# [cols processed]: 100%|██████████| 813/813 [00:00<00:00, 853.42it/s]

# %%
core_vars = {var for var in data.keys() if var.lower() in core_vars_superset}

# %%
print(f"{len(data)} questions.")
for k, v in data.items():
    print(f"{col(len(v['responses']), Fore.LIGHTWHITE_EX)} responses for {col(k, Fore.LIGHTRED_EX)}: {col(v['question'], Fore.LIGHTGREEN_EX)}")
    print(f"\tSupport: {" ".join([f"{col(c, Fore.LIGHTRED_EX)}) {col(w, Fore.LIGHTGREEN_EX)};" for c, w in v['support'].items()]) if v['support'] is not None and len(v['support']) > 0 else col('No support', Fore.LIGHTYELLOW_EX)}")
    print(f"\tType: {col(v['type'], Fore.LIGHTBLUE_EX)}")
    print("")
# Out:
# 813 questions.
# 3309 responses for fileversion: gss data file version
# 	Support: 7222.1) GSS 1972-2022 Release 1 (May 2023); 7222.2) GSS 1972-2022 Release 2 (November 2023); 7222.21) GSS 1972-2022 Release 2a (January 2024); 7222.3) GSS 1972-2022 Release 3 (April 2024); 7222.31) GSS 1972-2022 Release 3a (April 2024); 7222.4) GSS 1972-2022 Release 4 (November 2024); 7224.1) GSS 1972-2024 Release 1 (May 2025); 7224.2) GSS 1972-2024 Release 2 (October 2025);
# 	Type: categorical
#
# 3309 responses for year: gss year for this respondent
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for id: respondent id number
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for abany: abortion if woman wants for any reason
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abanyg: abortion if woman wants for any reason (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abdefect: strong chance of serious defect
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abdefectg: strong chance of serious defect (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abhlth: woman's health seriously endangered
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abhlthg: woman's health seriously endangered (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abnomore: married--wants no more children
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abnomoreg: married--wants no more children (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abpoor: low income--cant afford more children
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abpoorg: low income--cant afford more children (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abrape: pregnant as result of rape
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for abrapeg: pregnant as result of rape (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for absingle: not married
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for absingleg: not married (grid on web)
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for acpttg: accepting people
# 	Support: 1.0) too far; 2.0) about far enough; 3.0) not far enough;
# 	Type: categorical
#
# 3309 responses for adcoumed: would respondent have child on med by counselor's advice
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for addoc: would go to a medical doctor if he was respondent's child
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for adfam: would respondent get advice from family if child was respondent's
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for adoptus: immigrants living in us should adopt us culture
# 	Support: 1.0) adopt u.s. culture; 2.0) keep their own culture; 3.0) do both;
# 	Type: categorical
#
# 3309 responses for adpsy: would respondent go to a psychiatrist if child was respondent's
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for adtch: would respondent get advice from teachers child if was respondent's
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for adults: household members 18 yrs and older (household roster)
# 	Support: 1.0) 1 adult in household; 8.0) 8 or more;
# 	Type: scalar
#
# 3309 responses for adultsinhh: total adults in hh (household composition version)
# 	Support: 1.0) 1 adult in household; 8.0) 8 or more;
# 	Type: scalar
#
# 3309 responses for adults_exp: adults 18+ in hh(experimental version)
# 	Support: 1.0) 1 adult in household; 8.0) 8 or more;
# 	Type: scalar
#
# 3309 responses for affrmact: favor preference in hiring black people
# 	Support: 1.0) strongly favors; 2.0) not strongly favors; 3.0) not strongly opposes; 4.0) strongly opposes;
# 	Type: categorical
#
# 3309 responses for afraidof: people act as if they are afraid of respondent
# 	Support: 1.0) almost every day; 2.0) at least once a week; 3.0) a few times a month; 4.0) a few times a year; 5.0) less than once a year; 6.0) never;
# 	Type: categorical
#
# 3309 responses for age: age of respondent
# 	Support: 89.0) 89 or older;
# 	Type: scalar
#
# 3309 responses for agekdbrn: respondent's age when 1st child born
# 	Support: 17.0) 17 and younger; 45.0) 45 and older;
# 	Type: scalar
#
# 3309 responses for agetech: are older or younger people benefiting more from digital tech
# 	Support: 1.0) older people are benefitting more than younger people; 2.0) older people and younger people are benefitting equally; 3.0) younger people are benefitting more than older people; 4.0) neither older nor younger are benefitting;
# 	Type: categorical
#
# 3309 responses for aidrive: respondent's comfort with driverless car
# 	Support: 0.0) totally uncomfortable with this situation; 10.0) totally comfortable with this situation;
# 	Type: scalar
#
# 3309 responses for aimed: respondent's comfort with medical operation by robot
# 	Support: 0.0) totally uncomfortable with this situation; 10.0) totally comfortable with this situation;
# 	Type: scalar
#
# 3309 responses for aiworry: respondent worried that ai will take over many jobs done by humans
# 	Support: 1.0) very worried; 2.0) somewhat worried; 3.0) neither worried nor unworried; 4.0) not very worried; 5.0) not at all worried;
# 	Type: categorical
#
# 3309 responses for allergic: situation caused by food or chemical allergies
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for amancstr: how important to have american ancestry
# 	Support: 1.0) very important; 2.0) fairly important; 3.0) not very important; 4.0) not important at all;
# 	Type: categorical
#
# 3309 responses for ambetter: agree america is a better country
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for ambornin: how important to have been born in america
# 	Support: 1.0) very important; 2.0) fairly important; 3.0) not very important; 4.0) not important at all;
# 	Type: categorical
#
# 3309 responses for amchrstn: how important to be a christian
# 	Support: 1.0) very important; 2.0) fairly important; 3.0) not very important; 4.0) not important at all;
# 	Type: categorical
#
# 3309 responses for amcit: how important to have american citizenship
# 	Support: 1.0) very important; 2.0) fairly important; 3.0) not very important; 4.0) not important at all;
# 	Type: categorical
#
# 3309 responses for amcitizn: agree i would rather be a citizen of america
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for amfeel: how important to feel american
# 	Support: 1.0) very important; 2.0) fairly important; 3.0) not very important; 4.0) not important at all;
# 	Type: categorical
#
# 3309 responses for amgovt: how important to respect america's laws etc
# 	Support: 1.0) very important; 2.0) fairly important; 3.0) not very important; 4.0) not important at all;
# 	Type: categorical
#
# 3309 responses for amownway: america should follow its own interests
# 	Support: 1.0) agree strongly; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) disagree strongly;
# 	Type: categorical
#
# 3309 responses for amshamed: agree there are things make me ashamed
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for amtv: tv should give preference to american films
# 	Support: 1.0) agree strongly; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) disagree strongly;
# 	Type: categorical
#
# 3309 responses for attend: how often respondent attends religious services
# 	Support: 0.0) never; 1.0) less than once a year; 2.0) about once or twice a year; 3.0) several times a year; 4.0) about once a month; 5.0) 2-3 times a month; 6.0) nearly every week; 7.0) every week; 8.0) several times a week;
# 	Type: categorical
#
# 3309 responses for babies: household members less than 6 yrs old
# 	Support: 0.0) 0; 1.0) 1; 2.0) 2 or more;
# 	Type: categorical
#
# 3309 responses for babies_exp: kids 0-6 in hh(experimental version)
# 	Support: 0.0) 0; 1.0) 1; 2.0) 2 or more;
# 	Type: categorical
#
# 3309 responses for badchar: situation caused by own bad character
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for ballot: ballot used for interview
# 	Support: 1.0) ballot a; 2.0) ballot b; 3.0) ballot c; 4.0) ballot d;
# 	Type: categorical
#
# 3309 responses for befair: how often do you think people take advantage
# 	Support: 1.0) try to take advantage almost all of the time; 2.0) try to take advantage most of the time; 3.0) try to be fair most of the time; 4.0) try to be fair almost all of the time;
# 	Type: categorical
#
# 3309 responses for belikeus: agree better if people were more like americans
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for biasnews: news coverage about politics in america is biased
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for bible: feelings about the bible
# 	Support: 1.0) word of god; 2.0) inspired word; 3.0) ancient book; 4.0) other (vol);
# 	Type: categorical
#
# 3309 responses for biblenv: feelings about the bible (no volunteered response on web)
# 	Support: 1.0) word of god; 2.0) inspired word; 3.0) ancient book; 4.0) other (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for biblev: feelings about the bible (with volunteered response on web)
# 	Support: 1.0) word of god; 2.0) inspired word; 3.0) ancient book; 4.0) other (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for bizmoney: business leaders make money at expense of ordinary people
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for born: was respondent born in this country
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for breakdwn: how likely x is experiencing nervous breakdown
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for brneffrt: possible to become american if born elsewhere
# 	Support: 1.0) i definitely agree with statement a; 2.0) i agree more with statement a than with statement b; 3.0) i agree more with statement b than with statement a; 4.0) i definitely agree with statement b;
# 	Type: categorical
#
# 3309 responses for broadband: household has access to internet using broadband internet service
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for bullied: situation caused by having been bullied
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for bullpeer: would x bully peers
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for cantrust: people can be trusted or cant be too careful
# 	Support: 1.0) people can almost always be trusted; 2.0) people can usually be trusted; 3.0) you usually can't be too careful in dealing with people; 4.0) you almost always can't be too careful in dealing with people;
# 	Type: categorical
#
# 3309 responses for cappun: favor or oppose death penalty for murder
# 	Support: 1.0) favor; 2.0) oppose;
# 	Type: categorical
#
# 3309 responses for cctv: civil liberties - video surveillance
# 	Support: 1.0) definitely should have the right; 2.0) probably should have the right; 3.0) probably should not have the right; 4.0) definitely should not have the right;
# 	Type: categorical
#
# 3309 responses for charactr: how likely x s situation caused by bad character
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for chembal: situation by a chemical imbalance in the brain
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for childs: number of children
# 	Support: 8.0) 8 or more;
# 	Type: scalar
#
# 3309 responses for childsinhh: total children in hh (household composition version)
# 	Support: 0.0) 0; 1.0) 1; 2.0) 2; 3.0) 3; 4.0) 4; 5.0) 5; 6.0) 6 or more;
# 	Type: categorical
#
# 3309 responses for childs_exp: total children under 18 in hh (experimental verison)
# 	Support: 0.0) 0; 1.0) 1; 2.0) 2; 3.0) 3; 4.0) 4; 5.0) 5; 6.0) 6 or more;
# 	Type: categorical
#
# 3309 responses for chldadlt_asn: percent of adults you knew (friends, care takers, neighbors) during childhood wh
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldadlt_blk: percent of adults you knew (friends, care takers, neighbors) during childhood wh
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldadlt_hisp: percent of adults you knew (friends, care takers, neighbors) during childhood wh
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldadlt_oth: percent of adults you knew (friends, care takers, neighbors) during childhood wh
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldadlt_wht: percent of adults you knew (friends, care takers, neighbors) during childhood wh
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldchld_asn: percent of children you knew (friends, classmates) during childhood who were asi
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldchld_blk: percent of children you knew (friends, classmates) during childhood who were bla
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldchld_hisp: percent of children you knew (friends, classmates) during childhood who were lat
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldchld_oth: percent of children you knew (friends, classmates) during childhood who were som
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldchld_wht: percent of children you knew (friends, classmates) during childhood who were whi
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldfam_asn: percent of family during childhood who were asian
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldfam_blk: percent of family during childhood who were black
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldfam_hisp: percent of family during childhood who were latino
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldfam_oth: percent of family during childhood who were some other race
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldfam_wht: percent of family during childhood who were white
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldfrnd: how willing respondent have children make friends with ch
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for chldidel: ideal number of children
# 	Support: 7.0) 7 or more; 8.0) as many as you want;
# 	Type: scalar
#
# 3309 responses for chldprob: how serious respondent consider his or her problem
# 	Support: 1.0) very serious; 2.0) somewhat serious; 3.0) not very serious; 4.0) not at all serious;
# 	Type: categorical
#
# 3309 responses for chldsch: how willing respondent have child in same class of respondent's ch
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for chldshop_asn: percent of people who shopped at the supermarket during childhood who were asian
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldshop_blk: percent of people who shopped at the supermarket during childhood who were black
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldshop_hisp: percent of people who shopped at the supermarket during childhood who were latin
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldshop_oth: percent of people who shopped at the supermarket during childhood who were some
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldshop_wht: percent of people who shopped at the supermarket during childhood who were white
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for chldvig: vignette asked
# 	Support: 1.0) 1:  adhd, john, white, 8; 2.0) 2:  adhd, john, white, 14; 3.0) 3:  adhd, mary, white, 8; 4.0) 4:  adhd, mary, white, 14; 5.0) 5:  adhd, john, black, 8; 6.0) 6:  adhd, john, black, 14; 7.0) 7:  adhd, mary, black, 8; 8.0) 8:  adhd, mary, black, 14; 9.0) 9:  depression, john, white, 8; 10.0) 10: depression, john, white, 14; 11.0) 11: depression, mary, white, 8; 12.0) 12: depression, mary, white, 14; 13.0) 13: depression, john, black, 8; 14.0) 14: depression, john, black, 14; 15.0) 15: depression, mary, black, 8; 16.0) 16: depression, mary, black, 14; 17.0) 17: normal, john, white, 8; 18.0) 18: normal, john, white, 14; 19.0) 19: normal, mary, white, 8; 20.0) 20: normal, mary, white, 14; 21.0) 21: normal, john, black, 8; 22.0) 22: normal, john, black, 14; 23.0) 23: normal, mary, black, 8; 24.0) 24: normal, mary, black, 14; 25.0) 25: asthma, john, white, 8; 26.0) 26: asthma, john, white, 14; 27.0) 27: asthma, mary, white, 8; 28.0) 28: asthma, mary, white, 14; 29.0) 29: asthma, john, black, 8; 30.0) 30: asthma, john, black, 14; 31.0) 31: asthma, mary, black, 8; 32.0) 32: asthma, mary, black, 14; 33.0) 33: classic depression, john, white, 8; 34.0) 34: classic depression, john, white, 14; 35.0) 35: classic depression, mary, white, 8; 36.0) 36: classic depression, mary, white, 14; 37.0) 37: classic depression, john, black, 8; 38.0) 38: classic depression, john, black, 14; 39.0) 39: classic depression, mary, black, 8; 40.0) 40: classic depression, mary, black, 14; 41.0) 41: impulsivity, john, white, 8; 42.0) 42: impulsivity, john, white, 14; 43.0) 43: impulsivity, mary, white, 8; 44.0) 44: impulsivity, mary, white, 14; 45.0) 45: impulsivity, john, black, 8; 46.0) 46: impulsivity, john, black, 14; 47.0) 47: impulsivity, mary, black, 8; 48.0) 48: impulsivity, mary, black, 14; 49.0) 49: perfectionism, john, white, 8; 50.0) 50: perfectionism, john, white, 14; 51.0) 51: perfectionism, mary, white, 8; 52.0) 52: perfectionism, mary, white, 14; 53.0) 53: perfectionism, john, black, 8; 54.0) 54: perfectionism, john, black, 14; 55.0) 55: perfectionism, mary, black, 8; 56.0) 56: perfectionism, mary, black, 14;
# 	Type: categorical
#
# 3309 responses for chngdocs: changing official documents
# 	Support: 1.0) yes, the law should allow; 2.0) no, the law should not allow; 3.0) not sure;
# 	Type: categorical
#
# 3309 responses for citizen: are you a citizen of america?
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for class: subjective class identification
# 	Support: 1.0) lower class; 2.0) working class; 3.0) middle class; 4.0) upper class; 5.0) no class;
# 	Type: categorical
#
# 3309 responses for classtech: are poor or rich benefiting more from digital tech
# 	Support: 1.0) rich people are benefitting more than poor people; 2.0) rich and poor people are benefitting equally; 3.0) poor people are benefitting more than rich people; 4.0) neither rich people nor poor people are benefitting;
# 	Type: categorical
#
# 3309 responses for codeg: partner's highest degree
# 	Support: 0.0) less than high school; 1.0) high school; 2.0) associate/junior college; 3.0) bachelor's; 4.0) graduate;
# 	Type: categorical
#
# 3309 responses for coden: partner's denomination
# 	Support: 1.0) baptist; 2.0) methodist; 3.0) lutheran; 4.0) presbyterian; 5.0) episcopal; 6.0) other denomination; 7.0) no denomination or non-denominational church;
# 	Type: categorical
#
# 3309 responses for coeduc: highest year school completed, partner
# 	Support: 0.0) no formal schooling; 1.0) 1st grade; 2.0) 2nd grade; 3.0) 3rd grade; 4.0) 4th grade; 5.0) 5th grade; 6.0) 6th grade; 7.0) 7th grade; 8.0) 8th grade; 9.0) 9th grade; 10.0) 10th grade; 11.0) 11th grade; 12.0) 12th grade; 13.0) 1 year of college; 14.0) 2 years of college; 15.0) 3 years of college; 16.0) 4 years of college; 17.0) 5 years of college; 18.0) 6 years of college; 19.0) 7 years of college; 20.0) 8 or more years of college;
# 	Type: categorical
#
# 3309 responses for coevwork: partner ever work as long as a year
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for cofund: how fundamentalist is partner's current religion
# 	Support: 1.0) fundamentalist; 2.0) moderate; 3.0) liberal;
# 	Type: categorical
#
# 3309 responses for cohort: year of birth
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for cohrs1: number of hours partner worked last week
# 	Support: 89.0) 89+ hours;
# 	Type: scalar
#
# 3309 responses for cohrs2: no. of hours partner usually works a week
# 	Support: 89.0) 89+ hours;
# 	Type: scalar
#
# 3309 responses for coind10: partner's industry code (2010)
# 	Support: 170.0) crop production; 180.0) animal production; 190.0) forestry, except logging; 270.0) logging; 280.0) fishing, hunting, and trapping; 290.0) support activities for agriculture and forestry; 370.0) oil and gas extraction; 380.0) coal mining; 390.0) metal ore mining; 470.0) nonmetallic mineral mining and quarrying; 480.0) not specified type of mining; 490.0) support activities for mining; 570.0) electric power generation, transmission, and distribution; 580.0) natural gas distribution; 590.0) electric and gas, and other combinations; 670.0) water, steam, air-conditioning, and irrigation systems; 680.0) sewage treatment facilities; 690.0) not specified utilities; 770.0) construction; 1070.0) animal food, grain, and oilseed milling; 1080.0) sugar and confectionery products; 1090.0) fruit and vegetable preserving and specialty food manufacturing; 1170.0) dairy product manufacturing; 1180.0) animal slaughtering and processing; 1190.0) retail bakeries; 1270.0) bakeries, except retail; 1280.0) seafood and other miscellaneous foods, n.e.c.; 1290.0) not specified food industries; 1370.0) beverage manufacturing; 1390.0) tobacco manufacturing; 1470.0) fiber, yarn, and thread mills; 1480.0) fabric mills, except knitting mills; 1490.0) textile and fabric finishing and coating mills; 1570.0) carpet and rug mills; 1590.0) textile product mills, except carpet and rug; 1670.0) knitting fabric mills, and apparel knitting mills; 1680.0) cut and sew apparel manufacturing; 1690.0) apparel accessories and other apparel manufacturing; 1770.0) footwear manufacturing; 1790.0) leather tanning and finishing and other allied products manufacturing; 1870.0) pulp, paper, and paperboard mills; 1880.0) paperboard containers and boxes; 1890.0) miscellaneous paper and pulp products; 1990.0) printing and related support activities; 2070.0) petroleum refining; 2090.0) miscellaneous petroleum and coal products; 2170.0) resin, synthetic rubber and fibers, and filaments manufacturing; 2180.0) agricultural chemical manufacturing; 2190.0) pharmaceutical and medicine manufacturing; 2270.0) paint, coating, and adhesive manufacturing; 2280.0) soap, cleaning compound, and cosmetics manufacturing; 2290.0) industrial and miscellaneous chemicals; 2370.0) plastics product manufacturing; 2380.0) tire manufacturing; 2390.0) rubber product, except tire, manufacturing; 2470.0) pottery, ceramics, and plumbing fixture manufacturing; 2480.0) structural clay product manufacturing; 2490.0) glass and glass product manufacturing; 2570.0) cement, concrete, lime, and gypsum product manufacturing; 2590.0) miscellaneous nonmetallic mineral product manufacturing; 2670.0) iron and steel mills and steel product manufacturing; 2680.0) aluminum production and processing; 2690.0) nonferrous metal (except aluminum) production and processing; 2770.0) foundries; 2780.0) metal forgings and stampings; 2790.0) cutlery and hand tool manufacturing; 2870.0) structural metals, and boiler, tank, and shipping container manufacturing; 2880.0) machine shops; turned product; screw, nut, and bolt manufacturing; 2890.0) coating, engraving, heat treating and allied activities; 2970.0) ordnance; 2980.0) miscellaneous fabricated metal products manufacturing; 2990.0) not specified metal industries; 3070.0) agricultural implement manufacturing; 3080.0) construction, and mining and oil and gas field machinery manufacturing; 3090.0) commercial and service industry machinery manufacturing; 3170.0) metalworking machinery manufacturing; 3180.0) engines, turbines, and power transmission equipment manufacturing; 3190.0) machinery manufacturing, n.e.c.; 3290.0) not specified machinery manufacturing; 3360.0) computer and peripheral equipment manufacturing; 3370.0) communications, and audio and video equipment manufacturing; 3380.0) navigational, measuring, electromedical, and control instruments manufacturing; 3390.0) electronic component and product manufacturing, n.e.c.; 3470.0) household appliance manufacturin ...
# 	Type: categorical
#
# 3309 responses for colath: allow anti-religionist to teach
# 	Support: 4.0) yes, allowed to teach; 5.0) not allowed;
# 	Type: categorical
#
# 3309 responses for colcom: should communist teacher be fired
# 	Support: 4.0) yes, fired; 5.0) not fired;
# 	Type: categorical
#
# 3309 responses for colcomy: should communist teacher be fired y
# 	Support: 1.0) yes, fired; 2.0) not fired;
# 	Type: categorical
#
# 3309 responses for colmslm: allow anti-american muslim clergymen teaching in college
# 	Support: 4.0) yes, allowed to teach; 5.0) not allowed;
# 	Type: categorical
#
# 3309 responses for colrac: allow racist to teach
# 	Support: 4.0) yes, allowed to teach; 5.0) not allowed;
# 	Type: categorical
#
# 3309 responses for compuse: respondent use computer
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for conarmy: confidence in military
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conbus: confidence in major companies
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conclerg: confidence in organized religion
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for coneduc: confidence in education
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for confed: confid. in exec branch of fed govt
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for confinan: confid in banks & financial institutions
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for coninc: family income in constant dollars
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for conjudge: confid. in united states supreme court
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conlabor: confidence in organized labor
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conlabory: confidence in labor unions
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conlegis: confidence in congress
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conmedic: confidence in medicine
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conorelgsp: partner no religion
# 	Support: 1.0) atheist; 2.0) agnostic; 3.0) something else; 4.0) nothing in particular;
# 	Type: categorical
#
# 3309 responses for conpow: conflict between ordinary people and those in power
# 	Support: 1.0) strongly agree; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) strongly disagree;
# 	Type: categorical
#
# 3309 responses for conpress: confidence in press
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conrinc: respondent income in constant dollars
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for consci: confidence in scientific community
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for conscrp: importance of military service
# 	Support: 1.0) not at all important; 7.0) very important;
# 	Type: scalar
#
# 3309 responses for contv: confidence in television
# 	Support: 1.0) a great deal; 2.0) only some; 3.0) hardly any;
# 	Type: categorical
#
# 3309 responses for coocc10: partner's census occupation code (2010)
# 	Support: 10.0) chief executives; 20.0) general and operations managers; 30.0) legislators; 40.0) advertising and promotions managers; 50.0) marketing and sales managers; 60.0) public relations and fundraising managers; 100.0) administrative services managers; 110.0) computer and information systems managers; 120.0) financial managers; 135.0) compensation and benefits managers; 136.0) human resources managers; 137.0) training and development managers; 140.0) industrial production managers; 150.0) purchasing managers; 160.0) transportation, storage, and distribution managers; 205.0) farmers, ranchers, and other agricultural managers; 220.0) construction managers; 230.0) education administrators; 300.0) architectural and engineering managers; 310.0) food service managers; 325.0) funeral service managers; 330.0) gaming managers; 340.0) lodging managers; 350.0) medical and health services managers; 360.0) natural sciences managers; 400.0) postmasters and mail superintendents; 410.0) property, real estate, and community association managers; 420.0) social and community service managers; 425.0) emergency management directors; 430.0) managers, all other; 500.0) agents and business managers of artists, performers,; 510.0) buyers and purchasing agents, farm products; 520.0) wholesale and retail buyers, except farm products; 530.0) purchasing agents, except wholesale, retail, and farm products; 540.0) claims adjusters, appraisers, examiners, and investigators; 565.0) compliance officers; 600.0) cost estimators; 630.0) human resources workers; 640.0) compensation, benefits, and job analysis specialists; 650.0) training and development specialists; 700.0) logisticians; 710.0) management analysts; 725.0) meeting, convention, and event planners; 726.0) fundraisers; 735.0) market research analysts and marketing specialists; 740.0) business operations specialists, all other; 800.0) accountants and auditors; 810.0) appraisers and assessors of real estate; 820.0) budget analysts; 830.0) credit analysts; 840.0) financial analysts; 850.0) personal financial advisors; 860.0) insurance underwriters; 900.0) financial examiners; 910.0) credit counselors and loan officers; 930.0) tax examiners and collectors, and revenue agents; 940.0) tax preparers; 950.0) financial specialists, all other; 1005.0) computer and information research scientists; 1006.0) computer systems analysts; 1007.0) information security analysts; 1010.0) computer programmers; 1020.0) software developers, applications and systems software; 1030.0) web developers; 1050.0) computer support specialists; 1060.0) database administrators; 1105.0) network and computer systems administrators; 1106.0) computer network architects; 1107.0) computer occupations, all other; 1200.0) actuaries; 1210.0) mathematicians; 1220.0) operations research analysts; 1230.0) statisticians; 1240.0) miscellaneous mathematical science occupations; 1300.0) architects, except naval; 1310.0) surveyors, cartographers, and photogrammetrists; 1320.0) aerospace engineers; 1330.0) agricultural engineers; 1340.0) biomedical engineers; 1350.0) chemical engineers; 1360.0) civil engineers; 1400.0) computer hardware engineers; 1410.0) electrical and electronics engineers; 1420.0) environmental engineers; 1430.0) industrial engineers, including health and safety; 1440.0) marine engineers and naval architects; 1450.0) materials engineers; 1460.0) mechanical engineers; 1500.0) mining and geological engineers, including mining safety engineers; 1510.0) nuclear engineers; 1520.0) petroleum engineers; 1530.0) engineers, all other; 1540.0) drafters; 1550.0) engineering technicians, except drafters; 1560.0) surveying and mapping technicians; 1600.0) agricultural and food scientists; 1610.0) biological scientists; 1640.0) conservation scientists and foresters; 1650.0) medical scientists; 1660.0) life scientists, all other; 1700.0) astronomers and physicists; 1710.0) atmospheric and space scientists; 1720.0) chemists and materials sci ...
# 	Type: categorical
#
# 3309 responses for copres10: partner's occupational prestige score (2010)
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for copres105plus: partner's occupational prestige score using threshold method (2010)
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for corel: partner's religious preference
# 	Support: 1.0) protestant; 2.0) catholic; 3.0) jewish; 4.0) none; 5.0) other; 6.0) buddhism; 7.0) hinduism; 8.0) other eastern religions; 9.0) muslim/islam; 10.0) orthodox-christian; 11.0) christian; 12.0) native american; 13.0) inter-nondenominational;
# 	Type: categorical
#
# 3309 responses for corruptn: how widespread corruption is in pub service in america
# 	Support: 1.0) hardly anyone is involved; 2.0) a small number of people are involved; 3.0) a moderate number of people are involved; 4.0) a lot of people are involved; 5.0) almost everyone is involved;
# 	Type: categorical
#
# 3309 responses for cosei10: partner's socioeconomic index (2010)
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for cosei10educ: percentage of some college educ in coocc10 based on acs 2010
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for cosei10inc: percentage of $45k+ earners in coocc10 based on acs 2010
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for courts: courts dealing with criminals
# 	Support: 1.0) too harshly; 2.0) not harshly enough; 3.0) about right;
# 	Type: categorical
#
# 3309 responses for courtsnv: courts dealing with criminals (no volunteered response on web)
# 	Support: 1.0) too harshly; 2.0) not harshly enough; 3.0) about right (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for courtsv: courts dealing with criminals (with volunteered response on web)
# 	Support: 1.0) too harshly; 2.0) not harshly enough; 3.0) about right (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for cowksup: does partner supervise anyone
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for cowrkslf: partner self-emp. or works for somebody else
# 	Support: 1.0) self-employed; 2.0) someone else;
# 	Type: categorical
#
# 3309 responses for cowrkslf2: partner self-employed, with employees, or work for someone else
# 	Support: 1.0) yes, employees; 2.0) no, no employees;
# 	Type: categorical
#
# 3309 responses for cowrkslffam: partner work at family business or on family farm
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for cowrksta: partner's labor force status
# 	Support: 1.0) working full time; 2.0) working part time; 3.0) with a job, but not at work because of temporary illness, vacation, strike; 4.0) unemployed, laid off, looking for work; 5.0) retired; 6.0) in school; 7.0) keeping house; 8.0) other;
# 	Type: categorical
#
# 3309 responses for cutself: would x intentionally cut self
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for dangroth: x should be admitted to be hospitalized for treatment if dangerous to others
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for dangrslf: x should be admitted to be hospitalized for treatment if dangerous to x
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for dataprot: responsibility for internet data protection
# 	Support: 1.0) online companies - as they need to ensure they process personal information safely; 2.0) people - as they need to take care of their personal information; 3.0) public authorities - as they need to ensure that personal information is protected;
# 	Type: categorical
#
# 3309 responses for dateintv: date of interview
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for decmoney: how able is x to decide managing own money
# 	Support: 1.0) very able; 2.0) somewhat able; 3.0) not very able; 4.0) not able at all;
# 	Type: categorical
#
# 3309 responses for dectreat: how able is x to decide receive treatment
# 	Support: 1.0) very able; 2.0) somewhat able; 3.0) not very able; 4.0) not able at all;
# 	Type: categorical
#
# 3309 responses for degree: respondent's highest degree
# 	Support: 0.0) less than high school; 1.0) high school; 2.0) associate/junior college; 3.0) bachelor's; 4.0) graduate;
# 	Type: categorical
#
# 3309 responses for dem10fut: how well will democracy work in america in ten yrs
# 	Support: 0.0) very poorly; 10.0) very well;
# 	Type: scalar
#
# 3309 responses for dem10pst: how well did democracy work in america ten yrs ago
# 	Support: 0.0) very poorly; 10.0) very well;
# 	Type: scalar
#
# 3309 responses for demtoday: how well democracy work in america
# 	Support: 0.0) very poorly; 10.0) very well;
# 	Type: scalar
#
# 3309 responses for denom: specific denomination
# 	Support: 1.0) baptist; 2.0) methodist; 3.0) lutheran; 4.0) presbyterian; 5.0) episcopal; 6.0) other denomination; 7.0) no denomination or non-denominational church;
# 	Type: categorical
#
# 3309 responses for denom16: denomination in which respondent was raised
# 	Support: 1.0) baptist; 2.0) methodist; 3.0) lutheran; 4.0) presbyterian; 5.0) episcopal; 6.0) other denomination; 7.0) no denomination or non-denominational church;
# 	Type: categorical
#
# 3309 responses for devtype: are you taking this survey on a...
# 	Support: 1.0) laptop, netbook, or personal computer; 2.0) smartphone or mobile phone; 3.0) tablet; 4.0) something else;
# 	Type: categorical
#
# 3309 responses for diagnosd: respondent ever diagnosed with mh problem
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for dipged: diploma, ged, or other
# 	Support: 1.0) high school diploma; 2.0) ged; 3.0) other;
# 	Type: categorical
#
# 3309 responses for discaff: whites hurt by aff. action
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) very unlikely;
# 	Type: categorical
#
# 3309 responses for discaffm: a man won't get a job or promotion
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) very unlikely;
# 	Type: categorical
#
# 3309 responses for discaffw: a woman won't get a job or promotion
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) very unlikely;
# 	Type: categorical
#
# 3309 responses for discaffwnv: a woman won't get a job or promotion (no volunteered response on web)
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) very unlikely; 5.0) no opinion (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for discaffwv: a woman won't get a job or promotion (with volunteered response on web)
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) very unlikely; 5.0) no opinion (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for discipln: situation caused by lacking discipline in the
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for disrspct: respondent is treated with less courtesy or respect than others
# 	Support: 1.0) almost every day; 2.0) at least once a week; 3.0) a few times a month; 4.0) a few times a year; 5.0) less than once a year; 6.0) never;
# 	Type: categorical
#
# 3309 responses for divlaw: divorce laws
# 	Support: 1.0) easier; 2.0) more difficult; 3.0) stay as is;
# 	Type: categorical
#
# 3309 responses for divlawnv: divorce laws (no volunteered response on web)
# 	Support: 1.0) easier; 2.0) more difficult; 3.0) stay as is (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for divlawv: divorce laws (with volunteered response on web)
# 	Support: 1.0) easier; 2.0) more difficult; 3.0) stay as is (phone mode only: volunteered);
# 	Type: categorical
#
# 3309 responses for divorce: ever been divorced or separated
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for dofirst: here are the things you said {#secl_name} should do...  interviewer: read list
# 	Support: 1.0) talk to family and friends about it; 2.0) talk to a minister, priest, rabbi or other religious leader; 3.0) go to a general medical doctor for help; 4.0) go to a psychiatrist for help; 5.0) go to a therapist, or counselor, like a psychologist, social worker, or other mental health professional for help; 6.0) go to a spiritual or a natural healer for help; 7.0) join a self-help group where people with similar problems help each other; 8.0) take non-prescription medication, like over the counter sleeping pills; 9.0) take prescription medication; 10.0) check into a mental hospital;
# 	Type: categorical
#
# 3309 responses for dsndntpay: reparations for descendants of slaves
# 	Support: 1.0) yes; 2.0) no; 3.0) unsure;
# 	Type: categorical
#
# 3309 responses for dwelown: does respondent own or rent home?
# 	Support: 1.0) own or is buying; 2.0) pays rent; 3.0) other;
# 	Type: categorical
#
# 3309 responses for dwelown16: did rs family own or rent home when respondent was age 16
# 	Support: 1.0) owned or was buying; 2.0) paid rent; 3.0) other;
# 	Type: categorical
#
# 3309 responses for earnrs: how many in family earned money?
# 	Support: 3.0) 3 or more;
# 	Type: scalar
#
# 3309 responses for econstat: what do you think about the state of the economy these days in the united states
# 	Support: 1.0) very good; 2.0) good; 3.0) neither bad nor good; 4.0) bad; 5.0) very bad;
# 	Type: categorical
#
# 3309 responses for educ: highest year of school completed
# 	Support: 0.0) no formal schooling; 1.0) 1st grade; 2.0) 2nd grade; 3.0) 3rd grade; 4.0) 4th grade; 5.0) 5th grade; 6.0) 6th grade; 7.0) 7th grade; 8.0) 8th grade; 9.0) 9th grade; 10.0) 10th grade; 11.0) 11th grade; 12.0) 12th grade; 13.0) 1 year of college; 14.0) 2 years of college; 15.0) 3 years of college; 16.0) 4 years of college; 17.0) 5 years of college; 18.0) 6 years of college; 19.0) 7 years of college; 20.0) 8 or more years of college;
# 	Type: categorical
#
# 3309 responses for eductech: are educated or uneducated benefiting more from digital tech
# 	Support: 1.0) the highly educated are benefitting more than the less well educated; 2.0) the highly and the less well educated are benefitting equally; 3.0) the less well educated are benefitting more than the highly educated; 4.0) neither highly educated nor less well educated are benefitting;
# 	Type: categorical
#
# 3309 responses for emonitor1: should government be able to monitor online communication
# 	Support: 1.0) definitely should have the right; 2.0) probably should have the right; 3.0) probably should not have the right; 4.0) definitely should not have the right;
# 	Type: categorical
#
# 3309 responses for eqwlth: should govt reduce income differences
# 	Support: 1.0) the government should reduce income differences; 7.0) the government should not concern itself with reducing income differences;
# 	Type: scalar
#
# 3309 responses for eth1: 1st mentioned country of origin
# 	Support: 1.0) africa (general); 2.0) austria; 3.0) french canada; 4.0) other canada; 5.0) china; 6.0) czechoslovakia; 7.0) denmark; 8.0) england & wales; 9.0) finland; 10.0) france; 11.0) germany; 12.0) greece; 13.0) hungary; 14.0) ireland; 15.0) italy; 16.0) japan; 17.0) mexico; 18.0) netherlands; 19.0) norway; 20.0) philippines; 21.0) poland; 22.0) puerto rico; 23.0) russia; 24.0) scotland; 25.0) spain; 26.0) sweden; 27.0) switzerland; 28.0) west indies; 29.0) other; 30.0) american indian; 31.0) india; 32.0) portugal; 33.0) lithuania; 34.0) yugoslavia; 35.0) romania; 36.0) belgium; 37.0) arabic; 38.0) other spanish; 39.0) non-span west indies; 40.0) other asian; 41.0) other european; 97.0) american only; 101.0) turkey; 202.0) algeria; 203.0) congo; 204.0) egypt; 205.0) ethiopia; 206.0) kenya; 207.0) nigeria; 208.0) south africa; 209.0) sudan; 210.0) tanzania; 211.0) uganda; 299.0) other africa; 301.0) south korea; 302.0) bangladesh; 303.0) indonesia; 304.0) pakistan; 306.0) thailand; 307.0) vietnam; 401.0) iran; 402.0) iraq; 403.0) israel; 404.0) jordan; 405.0) saudi arabia; 406.0) syria; 407.0) uae; 408.0) yemen; 499.0) other middle east; 501.0) argentina; 502.0) bolivia; 503.0) brazil; 504.0) chile; 505.0) colombia; 506.0) ecuador; 507.0) french guiana; 508.0) guyana; 509.0) paraguay; 510.0) peru; 511.0) suriname; 512.0) uruguay; 513.0) venezuela; 599.0) other south america; 601.0) belize; 602.0) costa rica; 603.0) el salvador; 604.0) guatemala; 605.0) honduras; 606.0) nicaragua; 607.0) panama; 699.0) other central america; 799.0) other north america; 801.0) cuba; 802.0) haiti; 803.0) dominican republic; 804.0) jamaica; 899.0) other caribbean; 901.0) australia; 902.0) papua new guinea; 903.0) new zealand; 904.0) samoa; 999.0) other oceania;
# 	Type: categorical
#
# 3309 responses for ethnic: country of family origin
# 	Support: 1.0) africa (general); 2.0) austria; 3.0) french canada; 4.0) other canada; 5.0) china; 6.0) czechoslovakia; 7.0) denmark; 8.0) england & wales; 9.0) finland; 10.0) france; 11.0) germany; 12.0) greece; 13.0) hungary; 14.0) ireland; 15.0) italy; 16.0) japan; 17.0) mexico; 18.0) netherlands; 19.0) norway; 20.0) philippines; 21.0) poland; 22.0) puerto rico; 23.0) russia; 24.0) scotland; 25.0) spain; 26.0) sweden; 27.0) switzerland; 28.0) west indies; 29.0) other; 30.0) american indian; 31.0) india; 32.0) portugal; 33.0) lithuania; 34.0) yugoslavia; 35.0) romania; 36.0) belgium; 37.0) arabic; 38.0) other spanish; 39.0) non-span west indies; 40.0) other asian; 41.0) other european; 97.0) american only; 101.0) turkey; 202.0) algeria; 203.0) congo; 204.0) egypt; 205.0) ethiopia; 206.0) kenya; 207.0) nigeria; 208.0) south africa; 209.0) sudan; 210.0) tanzania; 211.0) uganda; 299.0) other africa; 301.0) south korea; 302.0) bangladesh; 303.0) indonesia; 304.0) pakistan; 306.0) thailand; 307.0) vietnam; 401.0) iran; 402.0) iraq; 403.0) israel; 404.0) jordan; 405.0) saudi arabia; 406.0) syria; 407.0) uae; 408.0) yemen; 499.0) other middle east; 501.0) argentina; 502.0) bolivia; 503.0) brazil; 504.0) chile; 505.0) colombia; 506.0) ecuador; 507.0) french guiana; 508.0) guyana; 509.0) paraguay; 510.0) peru; 511.0) suriname; 512.0) uruguay; 513.0) venezuela; 599.0) other south america; 601.0) belize; 602.0) costa rica; 603.0) el salvador; 604.0) guatemala; 605.0) honduras; 606.0) nicaragua; 607.0) panama; 699.0) other central america; 799.0) other north america; 801.0) cuba; 802.0) haiti; 803.0) dominican republic; 804.0) jamaica; 899.0) other caribbean; 901.0) australia; 902.0) papua new guinea; 903.0) new zealand; 904.0) samoa; 999.0) other oceania;
# 	Type: categorical
#
# 3309 responses for ethworld1: from what part of the world did your ancestors come?  europe
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld2: from what part of the world did your ancestors come?  africa
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld3: from what part of the world did your ancestors come?  asia
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld4: from what part of the world did your ancestors come?  middle east
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld5: from what part of the world did your ancestors come?  south america
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld6: from what part of the world did your ancestors come?  central america
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld7: from what part of the world did your ancestors come?  north america
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# 3309 responses for ethworld8: from what part of the world did your ancestors come?  caribbean
# 	Support: 0.0) no; 1.0) yes;
# 	Type: categorical
#
# ...
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for viggrp: how willing respondent would have a group home for x
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for viglabel: how likely x is experiencing vignettes
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for vigmar: how willing respondent would have x marry in respondent's family
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for vignei: how willing respondent would have x as a neighbor
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for vigsoc: how willing respondent would spend time socializing with x
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for vigversn: vignette version number
# 	Support: 1.0) 1:  alcohol dependence, john, white, eighth grade; 2.0) 2:  alcohol dependence, john, african american, eighth grade; 3.0) 3:  alcohol dependence, john, hispanic, eighth grade; 4.0) 4:  alcohol dependence, john, white, high school; 5.0) 5:  alcohol dependence, john, african american, high school; 6.0) 6:  alcohol dependence, john, hispanic, high school; 7.0) 7:  alcohol dependence, john, white, college; 8.0) 8:  alcohol dependence, john, african american, college; 9.0) 9:  alcohol dependence, john, hispanic, college; 10.0) 10: alcohol dependence, mary, white, eighth grade; 11.0) 11: alcohol dependence, mary, african american, eighth grade; 12.0) 12: alcohol dependence, mary, hispanic, eighth grade; 13.0) 13: alcohol dependence, mary, white, high school; 14.0) 14: alcohol dependence, mary, african american, high school; 15.0) 15: alcohol dependence, mary, hispanic, high school; 16.0) 16: alcohol dependence, mary, white, college; 17.0) 17: alcohol dependence, mary, african american, college; 18.0) 18: alcohol dependence, mary, hispanic, college; 19.0) 19: major depression, john, white, eighth grade; 20.0) 20: major depression, john, african american, eighth grade; 21.0) 21: major depression, john, hispanic, eighth grade; 22.0) 22: major depression, john, white, high school; 23.0) 23: major depression, john, african american, high school; 24.0) 24: major depression, john, hispanic, high school; 25.0) 25: major depression, john, white, college; 26.0) 26: major depression, john, african american, college; 27.0) 27: major depression, john, hispanic, college; 28.0) 28: major depression, mary, white, eighth grade; 29.0) 29: major depression, mary, african american, eighth grade; 30.0) 30: major depression, mary, hispanic, eighth grade; 31.0) 31: major depression, mary, white, high school; 32.0) 32: major depression, mary, african american, high school; 33.0) 33: major depression, mary, hispanic, high school; 34.0) 34: major depression, mary, white, college; 35.0) 35: major depression, mary, african american, college; 36.0) 36: major depression, mary, hispanic, college; 37.0) 37: schizophrenia, john, white, eighth grade; 38.0) 38: schizophrenia, john, african american, eighth grade; 39.0) 39: schizophrenia, john, hispanic, eighth grade; 40.0) 40: schizophrenia, john, white, high school; 41.0) 41: schizophrenia, john, african american, high school; 42.0) 42: schizophrenia, john, hispanic, high school; 43.0) 43: schizophrenia, john, white, college; 44.0) 44: schizophrenia, john, african american, college; 45.0) 45: schizophrenia, john, hispanic, college; 46.0) 46: schizophrenia, mary, white, eighth grade; 47.0) 47: schizophrenia, mary, african american, eighth grade; 48.0) 48: schizophrenia, mary, hispanic, eighth grade; 49.0) 49: schizophrenia, mary, white, high school; 50.0) 50: schizophrenia, mary, african american, high school; 51.0) 51: schizophrenia, mary, hispanic, high school; 52.0) 52: schizophrenia, mary, white, college; 53.0) 53: schizophrenia, mary, african american, college; 54.0) 54: schizophrenia, mary, hispanic, college; 55.0) 55: drug problem, john, white, eighth grade; 56.0) 56: drug problem, john, african american, eighth grade; 57.0) 57: drug problem, john, hispanic, eighth grade; 58.0) 58: drug problem, john, white, high school; 59.0) 59: drug problem, john, african american, high school; 60.0) 60: drug problem, john, hispanic, high school; 61.0) 61: drug problem, john, white, college; 62.0) 62: drug problem, john, african american, college; 63.0) 63: drug problem, john, hispanic, college; 64.0) 64: drug problem, mary, white, eighth grade; 65.0) 65: drug problem, mary, african american, eighth grade; 66.0) 66: drug problem, mary, hispanic, eighth grade; 67.0) 67: drug problem, mary, white, high school; 68.0) 68: drug problem, mary, african american, high school; 69.0) 69: drug problem, mary, hispanic, high school; 70.0) 70: drug problem, mary, white, college; 71.0) 71: drug problem, mary, african ameri ...
# 	Type: categorical
#
# 3309 responses for vigwork: how willing respondent would work closely with x on a job
# 	Support: 1.0) definitely willing; 2.0) probably willing; 3.0) probably unwilling; 4.0) definitely unwilling;
# 	Type: categorical
#
# 3309 responses for violpeop: would child do something violent toward other
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not likely at all;
# 	Type: categorical
#
# 3309 responses for violself: would child do something violent to own self
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not likely at all;
# 	Type: categorical
#
# 3309 responses for violtv: situation caused by watching violent tv
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for visitors: number of visitor's in household
# 	Support: 0.0) no visitors; 1.0) 1 visitor; 2.0) 2 visitors; 3.0) 3 visitors; 4.0) 4 visitors;
# 	Type: categorical
#
# 3309 responses for vote16: remember if voted in 2016 election
# 	Support: 1.0) voted; 2.0) did not vote; 3.0) ineligible;
# 	Type: categorical
#
# 3309 responses for vote20: remember if voted in 2020 election
# 	Support: 1.0) voted; 2.0) did not vote; 3.0) ineligible;
# 	Type: categorical
#
# 3309 responses for voteprob: voting problem in us elections
# 	Support: 1.0) very strongly ineligible voters being allowed to vote; 2.0) moderately strongly ineligible voters being allowed to vote; 3.0) a little ineligible voters being allowed to vote; 4.0) a little eligible voters not being allowed to vote; 5.0) moderately strongly eligible voters not being allowed to vote; 6.0) very strongly eligible voters not being allowed to vote;
# 	Type: categorical
#
# 3309 responses for vpsu: variance primary sampling unit
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for vstrat: variance stratum
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for watchgov: how important to keep watch on action of govt
# 	Support: 1.0) not at all important; 7.0) very important;
# 	Type: scalar
#
# 3309 responses for wayraise: how likely x s situation caused by the way raised
# 	Support: 1.0) very likely; 2.0) somewhat likely; 3.0) not very likely; 4.0) not at all likely;
# 	Type: categorical
#
# 3309 responses for webmob: respondent uses home internet through mobile device
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for webnews: reliability of news on web
# 	Support: 1.0) very unreliable; 2.0) somewhat unreliable; 3.0) somewhat reliable; 4.0) very reliable;
# 	Type: categorical
#
# 3309 responses for weekswrk: weeks respondent worked last year
# 	Support: 0.0) none or zero;
# 	Type: scalar
#
# 3309 responses for whatco2: classify place where partners works
# 	Support: 1.0) manufacturing; 2.0) wholesale trade; 3.0) retail trade; 4.0) other (agriculture, construction, service, government, etc.);
# 	Type: categorical
#
# 3309 responses for whatma2: how would you classify the place where mother (or youngest same-sex parent) work
# 	Support: 1.0) manufacturing; 2.0) wholesale trade; 3.0) retail trade; 4.0) other (agriculture, construction, service, government, etc.);
# 	Type: categorical
#
# 3309 responses for whatpa2: how would you classify the place where father (or oldest same-sex parent) worked
# 	Support: 1.0) manufacturing; 2.0) wholesale trade; 3.0) retail trade; 4.0) other (agriculture, construction, service, government, etc.);
# 	Type: categorical
#
# 3309 responses for whatslf2: how would you classify the place where you {#whatslf2fill}? was this mainly...?
# 	Support: 1.0) manufacturing; 2.0) wholesale trade; 3.0) retail trade; 4.0) other (agriculture, construction, service, government, etc.);
# 	Type: categorical
#
# 3309 responses for whatsp2: classify place where spouse works
# 	Support: 1.0) manufacturing; 2.0) wholesale trade; 3.0) retail trade; 4.0) other (agriculture, construction, service, government, etc.);
# 	Type: categorical
#
# 3309 responses for whovote24: voting intention in 2024 election (pre july 25 2024)
# 	Support: 1.0) donald trump; 2.0) joe biden; 3.0) someone else; 4.0) probably not vote;
# 	Type: categorical
#
# 3309 responses for whovote24a: voting intention in 2024 election (post july 25 2024)
# 	Support: 1.0) donald trump; 2.0) kamala harris; 3.0) someone else; 4.0) probably not vote;
# 	Type: categorical
#
# 3309 responses for whovotets: voting intention - time series
# 	Support: 1.0) republican candidate; 2.0) democratic candidate; 3.0) someone else; 4.0) probably not vote;
# 	Type: categorical
#
# 3309 responses for widowed: ever been widowed
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wksub: does respondent or spouse have supervisor
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wksub1: does respondent or spouse or partner have a supervisor
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wksubs: does supervisor have supervisor
# 	Support: 3.0) yes; 4.0) no;
# 	Type: categorical
#
# 3309 responses for wksubs1: does supervisor have supervisor
# 	Support: 3.0) yes; 4.0) no;
# 	Type: categorical
#
# 3309 responses for wksup: does respondent or spouse supervise anyone
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wksup1: does respondent or spouse or partner supervise anyone
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wksups: does subordinate supervise anyone
# 	Support: 3.0) yes; 4.0) no;
# 	Type: categorical
#
# 3309 responses for wksups1: does subordinant supervise anyone
# 	Support: 3.0) yes; 4.0) no;
# 	Type: categorical
#
# 3309 responses for wlthblks: rich - poor
# 	Support: 1.0) 1 - rich; 7.0) 7 - poor;
# 	Type: scalar
#
# 3309 responses for wlthhsps: rich - poor
# 	Support: 1.0) 1 - rich; 7.0) 7 - poor;
# 	Type: scalar
#
# 3309 responses for wlthwhts: rich - poor
# 	Support: 1.0) 1 - rich; 7.0) 7 - poor;
# 	Type: scalar
#
# 3309 responses for worda: word a
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordb: word b
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordc: word c
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordd: word d
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for worde: word e
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordf: word f
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordg: word g
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordh: word h
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordi: word i
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordj: word j
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordk: word k
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordl: word l
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordn: word n
# 	Support: 0.0) incorrect answer; 1.0) correct answer;
# 	Type: categorical
#
# 3309 responses for wordsum: number words correct in vocabulary test
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for workblks: hard working - lazy
# 	Support: 1.0) 1 - hard-working; 7.0) 7 - lazy;
# 	Type: scalar
#
# 3309 responses for workhard: to work hard
# 	Support: 1.0) most important; 2.0) 2nd important; 3.0) 3rd important; 4.0) 4th important; 5.0) least important;
# 	Type: categorical
#
# 3309 responses for workhsps: hard working -lazy
# 	Support: 1.0) 1 - hard-working; 7.0) 7 - lazy;
# 	Type: scalar
#
# 3309 responses for workless: cut back on your work?
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for workwhts: hard working - lazy
# 	Support: 1.0) 1 - hard-working; 7.0) 7 - lazy;
# 	Type: scalar
#
# 3309 responses for wrkgovt1: govt employee
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wrkgovt2: private employee
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wrkslf: respondent self-emp or works for somebody
# 	Support: 1.0) self-employed; 2.0) someone else;
# 	Type: categorical
#
# 3309 responses for wrkslffam: does respondent work in family business or farm
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for wrkstat: labor force status
# 	Support: 1.0) working full time; 2.0) working part time; 3.0) with a job, but not at work because of temporary illness, vacation, strike; 4.0) unemployed, laid off, looking for work; 5.0) retired; 6.0) in school; 7.0) keeping house; 8.0) other;
# 	Type: categorical
#
# 3309 responses for wrkwayup: black people overcome prejudice without favors
# 	Support: 1.0) agree strongly; 2.0) agree somewhat; 3.0) neither agree nor disagree; 4.0) disagree somewhat; 5.0) disagree strongly;
# 	Type: categorical
#
# 3309 responses for wrldgovt: international bodies should enforce environment
# 	Support: 1.0) agree strongly; 2.0) agree; 3.0) neither agree nor disagree; 4.0) disagree; 5.0) disagree strongly;
# 	Type: categorical
#
# 3309 responses for wtssnrps: person post-stratification weight, nonrespondents adjusted
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for wtssps: person post-stratification weight
# 	Support: No support
# 	Type: scalar
#
# 3309 responses for xmarsex: sex with person other than spouse
# 	Support: 1.0) always wrong; 2.0) almost always wrong; 3.0) wrong only sometimes; 4.0) not wrong at all; 5.0) other;
# 	Type: categorical
#
# 3309 responses for xmovie: seen x-rated movie in last year
# 	Support: 1.0) yes; 2.0) no;
# 	Type: categorical
#
# 3309 responses for xmoviey: seen pornography in past year
# 	Support: 1.0) never; 2.0) less than once a year; 3.0) about once or twice a year; 4.0) several times a year; 5.0) about once a month; 6.0) 2-3 times a month; 7.0) nearly every week; 8.0) every week; 9.0) once a day; 10.0) several times a day;
# 	Type: categorical
#
# 3309 responses for xnorcsiz: expanded norc size code
# 	Support: 1.0) a large central city (over 250,000); 2.0) a medium size central city (50,000 to 250,000); 3.0) a suburb of a large central city; 4.0) a suburb of a medium size central city; 5.0) an unincorporated area of a large central city (division, township, etc.); 6.0) an unincorporated area of a medium central city; 7.0) not within an smsa, (within a county) and a small city (10,000 to 49,999); 8.0) a town or village (2,500 to 9,999); 9.0) an incorporated area less than 2,500 or an unincorporated area of 1,000 to 2,499; 10.0) open country within larger civil divisions (division, township, etc.);
# 	Type: categorical
#
# 3309 responses for yousup: how many people do you supervise directly
# 	Support: 0.0) 0 people;
# 	Type: scalar

# %%
def inspect_question(code: str, resp_id: int) -> None:
    assert code in data, f"Question code {code} not found."
    qst_data = data[code]
    assert 0 <= resp_id < len(qst_data["responses"]), f"Response ID {resp_id} out of range."
    print(f"Question: {col(qst_data['question'], Fore.LIGHTGREEN_EX)}")
    print(f"Response: {col(qst_data['responses'][resp_id], Fore.LIGHTGREEN_EX)} ({col(qst_data['type'], Fore.LIGHTBLUE_EX)})")
    print(f"In core: {col(code in core_vars, Fore.LIGHTGREEN_EX)}")
    if qst_data['support']:
        print(f"Support:")
        for code, label in qst_data['support'].items():
            print(f"\t{col(code, Fore.LIGHTRED_EX)}: {col(label, Fore.LIGHTGREEN_EX)}")

interact(inspect_question, code=data.keys(), resp_id=(0, 1000, 1));
# Out:
# interactive(children=(Dropdown(description='code', options=('fileversion', 'year', 'id', 'abany', 'abanyg', 'a…

# %%
def inspect_person(resp_id: int, verbose: bool, in_core: bool) -> None:
    assert 0 <= resp_id < len(next(iter(data.values()))["responses"]), f"Response ID {resp_id} out of range."
    count = 0
    for qst_code in data.keys():
        qst_data = data[qst_code]
        resp = qst_data['responses'][resp_id]
        if resp is not None and (not in_core or qst_code in core_vars):
            count += 1
            print(f"{count}) {col(qst_code, Fore.LIGHTRED_EX)}: {col(qst_data['question'], Fore.LIGHTGREEN_EX)}")
            print(f"\tResponse: {col(resp, Fore.LIGHTGREEN_EX)} ({col(qst_data['type'], Fore.LIGHTBLUE_EX)})")
            if qst_data['support'] and verbose:
                print(f"\tSupport:")
                for code, label in qst_data['support'].items():
                    print(f"\t\t{col(code, Fore.LIGHTRED_EX)}: {col(label, Fore.LIGHTGREEN_EX)}")
            print("")

    print(f"Included {count} questions.")

interact(inspect_person, resp_id=(0, 1000, 1), verbose=False, in_core=False);
# Out:
# interactive(children=(IntSlider(value=500, description='resp_id', max=1000), Checkbox(value=False, description…

# %%
def infer_race(row: dict[str, Any]) -> str | None:
    race_mapping = {
        'raceacs1': 'White',
        'raceacs2': 'Black or African American', 
        'raceacs3': 'American Indian or Alaska Native',
        'raceacs4': 'Asian Indian',
        'raceacs5': 'Chinese',
        'raceacs6': 'Filipino',
        'raceacs7': 'Japanese',
        'raceacs8': 'Korean',
        'raceacs9': 'Vietnamese',
        'raceacs10': 'Other Asian',
        'raceacs14': 'Native Hawaiian or Other Pacific Islander',
        'raceacs15': 'Some Other Race',
        'raceacs16': 'Hispanic or Latino'
    }
    
    identities = []
    for var, label in race_mapping.items():
        if var in row and row[var] == "yes":
            identities.append(label.lower())
    
    if not identities:
        return None
    elif len(identities) == 1:
        return identities[0]
    else:
        if len(identities) == 2:
            return f"{identities[0]}, and {identities[1]}"
        else:
            return ", ".join(identities[:-1]) + f", and {identities[-1]}"

# %%
demographic_vars = [
    'age',       # age of respondent
    'sex',       # respondent's sex  
    'race',      # race of respondent
    'relig',     # respondent's religious preference
    'marital',   # marital status
    'wrkstat',   # labor force status
    'polviews',  # think of self as liberal or conservative
    'born',
    'year',
    'educ'
]

def inspect_demographics(resp_id: int, verbose: bool) -> None:
    assert 0 <= resp_id < len(next(iter(data.values()))["responses"]), f"Response ID {resp_id} out of range."
    count = 0
    for qst_code in demographic_vars:
        qst_data = data[qst_code]
        resp = qst_data['responses'][resp_id]
        supp = qst_data['support']
        if qst_code == "race":
            resp = infer_race({k.lower(): v for k, v in zip(data.keys(), [data[k]['responses'][resp_id] for k in data.keys()])})
            supp = None
        if resp is None:
            resp = "not specified"
        print(f"{col(qst_code, Fore.LIGHTRED_EX)}: {col(qst_data['question'], Fore.LIGHTGREEN_EX)}")
        print(f"\tResponse: {col(resp, Fore.LIGHTGREEN_EX)} ({col(qst_data['type'], Fore.LIGHTBLUE_EX)})")
        if supp and verbose:
            print(f"\tSupport:")
            for code, label in supp.items():
                print(f"\t\t{col(code, Fore.LIGHTRED_EX)}: {col(label, Fore.LIGHTGREEN_EX)}")
        print("")

interact(inspect_demographics, resp_id=(0, 1000, 1), verbose=False);
# Out:
# interactive(children=(IntSlider(value=500, description='resp_id', max=1000), Checkbox(value=False, description…

# %% [markdown]
# *TODO*
# 1. Identify which questions belong to GSS Core module and which ones do not.
# 2. Automate production of a "scratch.json" for each respondent.
